# %%
import pandas as pd
import numpy as np
table=pd.read_html('https://search.naver.com/search.naver?sm=top_hty&fbm=1&ie=utf8&query=2019+%EC%88%98%EB%8A%A5+%EB%93%B1%EA%B8%89%EC%BB%B7')
table[1]
#2019 수능 국어 등급컷 1~5등급컷
# Out:
#    등급  구분점수  인원(명)  비율(%)
# 0   1   131  23282   4.82
# 1   2   125  35257   7.30
# 2   3   117  59438  12.30
# 3   4   107  80221  16.61
# 4   5    95  95752  19.82

# %%
import pandas as pd
import numpy as np
table=pd.read_html('https://search.naver.com/search.naver?sm=top_hty&fbm=1&ie=utf8&query=2019+%EC%88%98%EB%8A%A5+%EB%93%B1%EA%B8%89%EC%BB%B7')
table[2]
#2019 수능 국어 등급컷 6~9등급컷
# Out:
#     등급   구분점수    인원(명)  비율(%)
# 0  6.0     83  83182.0  17.22
# 1  7.0     72  56941.0  11.79
# 2  8.0     64  32537.0   6.74
# 3  9.0  64 미만  16458.0   3.41
# 4  NaN    NaN      NaN    NaN

# %%
import pandas as pd
import numpy as  np
college=pd.read_html('https://ko.wikipedia.org/wiki/%EB%8C%80%ED%95%99%EB%B3%84_%EB%85%B8%EB%B2%A8%EC%83%81_%EC%88%98%EC%83%81%EC%9E%90_%EB%AA%A9%EB%A1%9D')
college[0]
# Out:
#     순위                대학   국가  총 수상자 수  총 수 자연 과학  물리학상    화학상  생리학·의학상  경제학상  \
# 0    1           하버드 대학교   미국      160        112    33     36       43    32
# 1    2         케임브리지 대학교   영국      120         97    36     30       31    15
# 2    3     캘리포니아 대학교 버클리   미국      107         80    33     30       17    24
# 3    4           시카고 대학교   미국      100         62    32     19       11    33
# 4    5          컬럼비아 대학교   미국       96         70    33     15       22    15
# 5    5       매사추세츠 공과대학교   미국       96         61    33     16       12    34
# 6    7          스탠퍼드 대학교   미국       83         55    26     13       16    26
# 7    8       캘리포니아 공과대학교   미국       74         67    30     17       21     6
# 8    9          옥스퍼드 대학교   영국       72         52    14     19       19    10
# 9   10          프린스턴 대학교   미국       68         41    28      9        4    21
# 10  11            예일 대학교   미국       62         33     8     11       14    22
# ...

# %%
import pandas as pd
import numpy as  np
mr=pd.read_html('https://search.naver.com/search.naver?sm=tab_hty.top&where=nexearch&query=%ED%99%98%EC%9C%A8&oquery=2019+%EC%88%98%EB%8A%A5+%EB%93%B1%EA%B8%89%EC%BB%B7&tqi=UBBHpsp0JywssKErsw8ssssst60-145012')
df=mr[1]                  #mr[1]에 있는 표 내용들을 df로 저장시킨다
df.to_csv('mr.csv')
df
# Out:
#           통화명    매매기준율         전일대비     등락률
# 0      미국 USD  1186.90   전일대비하락7.10  -0.59%
# 1  일본 JPY 100  1091.55   전일대비하락9.37  -0.85%
# 2    유럽연합 EUR  1312.71   전일대비하락9.05  -0.68%
# 3      중국 CNY   169.57   전일대비하락0.60  -0.35%
# 4      영국 GBP  1544.22  전일대비하락16.04  -1.03%
# 5      호주 AUD   797.30   전일대비하락1.96  -0.25%
# 6     캐나다 CAD   893.21   전일대비하락8.47  -0.94%
# 7    뉴질랜드 NZD   767.51   전일대비하락4.59  -0.59%

# %%
# 이것을 통해 우리는 pandas 라이브러리를 이용해 사이트에있는 표를 직접 jupyter에 이용할수 있고 추가적으로
#          df.to_csv('test.csv') 라는 것으로 파일 자체를 저장해 직장에서도 유용히 쓸수있다.
